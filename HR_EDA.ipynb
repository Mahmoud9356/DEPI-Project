# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmoud9356/DEPI-Project/blob/main/HR_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Importing the needed libraries***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***Reading the needed files***

# %%
df1=pd.read_csv('Cleaned_Employee.csv')
df2=pd.read_excel('EducationLevel.xlsx')
df3=pd.read_excel('PerformanceRating.xlsx')
df4=pd.read_excel('RatingLevel.xlsx')
df5=pd.read_excel('SatisfiedLevel.xlsx')

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ***Review the information of data***

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               1470 non-null   object
#  1   FirstName                1470 non-null   object
#  2   LastName                 1470 non-null   object
#  3   Gender                   1470 non-null   object
#  4   Age                      1470 non-null   int64
#  5   BusinessTravel           1470 non-null   object
#  6   Department               1470 non-null   object
#  7   DistanceFromHome (KM)    1470 non-null   int64
#  8   State                    1470 non-null   object
#  9   Ethnicity                1470 non-null   object
#  10  Education                1470 non-null   int64
#  11  EducationField           1470 non-null   object
#  12  JobRole                  1470 non-null   object
#  13  MaritalStatus            1470 non-null   object
# ...

# %% [markdown]
# ***Review the top 5 rows of employee table***

# %%
df1.head()
# Out:
#   EmployeeID   FirstName LastName      Gender  Age BusinessTravel  \
# 0  3012-1A41    Leonelle    Simco      Female   30    Some Travel
# 1  CBCB-9C9D     Leonerd    Aland        Male   38    Some Travel
# 2  95D7-1CE9       Ahmed    Sykes        Male   43    Some Travel
# 3  47A0-559B  Ermentrude   Berrie  Non-Binary   39    Some Travel
# 4  42CC-040A       Stace   Savege      Female   29    Some Travel
#
#         Department  DistanceFromHome (KM) State                Ethnicity  ...  \
# 0            Sales                     27    IL                    White  ...
# 1            Sales                     23    CA                    White  ...
# 2  Human Resources                     29    CA  Asian or Asian American  ...
# 3       Technology                     12    IL                    White  ...
# 4  Human Resources                     29    CA                    White  ...
#
#    MaritalStatus  Salary StockOptionLevel OverTime  HireDate  Attrition  \
# ...

# %% [markdown]
# ***Review the size of the employee table***

# %%
df1.shape
# Out:
# (1470, 23)

# %% [markdown]
# ***Review the size of the education level table***

# %%
df2.shape
# Out:
# (5, 2)

# %% [markdown]
# ***Review the size of the performance level table***

# %%
df3.shape
# Out:
# (6709, 11)

# %% [markdown]
# ***Review the size of the rating level table***

# %%
df4.shape
# Out:
# (1470, 23)

# %% [markdown]
# ***Review the size of the satisfied level table***

# %%
df5.shape
# Out:
# (5, 2)

# %% [markdown]
# ***Review the columns of the employee table***

# %%
df1.columns
# Out:
# Index(['EmployeeID', 'FirstName', 'LastName', 'Gender', 'Age',
#        'BusinessTravel', 'Department', 'DistanceFromHome (KM)', 'State',
#        'Ethnicity', 'Education', 'EducationField', 'JobRole', 'MaritalStatus',
#        'Salary', 'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
#        'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ***Review the columns of the education level table***

# %%
df2.columns
# Out:
# Index(['EducationLevelID', 'EducationLevel'], dtype='object')

# %% [markdown]
# ***Review the columns of the performance rating table***

# %%
df3.columns
# Out:
# Index(['PerformanceID', 'EmployeeID', 'ReviewDate', 'EnvironmentSatisfaction',
#        'JobSatisfaction', 'RelationshipSatisfaction',
#        'TrainingOpportunitiesWithinYear', 'TrainingOpportunitiesTaken',
#        'WorkLifeBalance', 'SelfRating', 'ManagerRating'],
#       dtype='object')

# %% [markdown]
# ***Review the columns of the rating level table***

# %%
df4.columns
# Out:
# Index(['EmployeeID', 'FirstName', 'LastName', 'Gender', 'Age',
#        'BusinessTravel', 'Department', 'DistanceFromHome (KM)', 'State',
#        'Ethnicity', 'Education', 'EducationField', 'JobRole', 'MaritalStatus',
#        'Salary', 'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
#        'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ***Review the columns of the satisfied level table***

# %%
df5.columns
# Out:
# Index(['SatisfactionID', 'SatisfactionLevel'], dtype='object')

# %% [markdown]
# ***Retrieve the average of age***

# %%
print(df1['Age'].mean())
# Out:
# 28.989795918367346

# %% [markdown]
# ***Retrieve the employee data of maximum salary***

# %%
print(df1.iloc[df1['Salary'].idxmax()])
# Out:
# EmployeeID                          17AE-E715
# FirstName                              Norbie
# LastName                              Mosdill
# Gender                                   Male
# Age                                        31
# BusinessTravel             Frequent Traveller
# Department                         Technology
# DistanceFromHome (KM)                      38
# State                                      CA
# Ethnicity                               White
# Education                                   1
# EducationField               Computer Science
# JobRole                     Analytics Manager
# MaritalStatus                        Divorced
# Salary                                 547204
# StockOptionLevel                            1
# OverTime                                  Yes
# HireDate                            28/9/2014
# Attrition                                  No
# YearsAtCompany                              8
# ...

# %% [markdown]
# ***Retrieve the employee data of minimum salary***

# %%
print(df1.iloc[df1['Salary'].idxmin()])
# Out:
# EmployeeID                        ADF8-AD57
# FirstName                              Trip
# LastName                            Bennell
# Gender                                 Male
# Age                                      27
# BusinessTravel                  Some Travel
# Department                       Technology
# DistanceFromHome (KM)                    28
# State                                    CA
# Ethnicity                             White
# Education                                 3
# EducationField             Computer Science
# JobRole                      Data Scientist
# MaritalStatus                        Single
# Salary                                20387
# StockOptionLevel                          0
# OverTime                                 No
# HireDate                          16/8/2016
# Attrition                               Yes
# YearsAtCompany                            0
# YearsInMostRecentRole                     0
# ...

# %% [markdown]
# ***Retrieve the employee data with maximum years at company***

# %%
print(df1.iloc[df1['YearsAtCompany'].idxmax()])
# Out:
# EmployeeID                       3012-1A41
# FirstName                         Leonelle
# LastName                             Simco
# Gender                              Female
# Age                                     30
# BusinessTravel                 Some Travel
# Department                           Sales
# DistanceFromHome (KM)                   27
# State                                   IL
# Ethnicity                            White
# Education                                5
# EducationField                   Marketing
# JobRole                    Sales Executive
# MaritalStatus                     Divorced
# Salary                              102059
# StockOptionLevel                         1
# OverTime                                No
# HireDate                          3/1/2012
# Attrition                               No
# YearsAtCompany                          10
# YearsInMostRecentRole                    4
# YearsSinceLastPromotion                  9
# ...

# %% [markdown]
# ***Retrieve the employee data with minimum years at company***

# %%
print(df1.iloc[df1['YearsAtCompany'].idxmin()])
# Out:
# EmployeeID                        8D34-EBDF
# FirstName                             Giles
# LastName                             Bilham
# Gender                                 Male
# Age                                      29
# BusinessTravel                  Some Travel
# Department                  Human Resources
# DistanceFromHome (KM)                    14
# State                                    IL
# Ethnicity                  Native Hawaiian
# Education                                 4
# EducationField             Technical Degree
# JobRole                           Recruiter
# MaritalStatus                       Married
# Salary                                46703
# StockOptionLevel                          0
# OverTime                                 No
# HireDate                          31/7/2014
# Attrition                               Yes
# YearsAtCompany                            0
# YearsInMostRecentRole                     0
# ...

# %% [markdown]
# Retrieve the average of years at company

# %%
print(df1['YearsAtCompany'].mean())
# Out:
# 4.562585034013606

# %% [markdown]
# ***Years at Company & Attrition***

# %%
sns.countplot(x='YearsAtCompany', data=df1, palette='mako',hue='Attrition')
plt.title('Years at Company vs Attrition')
plt.show()

# %% [markdown]
# ***Retrieve the employee data with maximum year in most recent role***

# %%
print(df1.iloc[df1['YearsInMostRecentRole'].idxmax()])
# Out:
# EmployeeID                           47A0-559B
# FirstName                           Ermentrude
# LastName                                Berrie
# Gender                              Non-Binary
# Age                                         39
# BusinessTravel                     Some Travel
# Department                          Technology
# DistanceFromHome (KM)                       12
# State                                       IL
# Ethnicity                                White
# Education                                    3
# EducationField                Computer Science
# JobRole                    Engineering Manager
# MaritalStatus                          Married
# Salary                                  293132
# StockOptionLevel                             0
# OverTime                                    No
# HireDate                              5/1/2012
# Attrition                                   No
# YearsAtCompany                              10
# ...

# %% [markdown]
# ***Retrieve the employee data with minimum year in most recent role***

# %%
print(df1.iloc[df1['YearsInMostRecentRole'].idxmin()])
# Out:
# EmployeeID                                        BFF3-AADC
# FirstName                                            Collen
# LastName                                             Sedman
# Gender                                               Female
# Age                                                      31
# BusinessTravel                                   No Travel
# Department                                  Human Resources
# DistanceFromHome (KM)                                    25
# State                                                    NY
# Ethnicity                  American Indian or Alaska Native
# Education                                                 2
# EducationField                                    Marketing
# JobRole                                           Recruiter
# MaritalStatus                                      Divorced
# Salary                                                55682
# StockOptionLevel                                          1
# ...

# %% [markdown]
# ***Retrieve the average of years in most recent role***

# %%
print(df1['YearsInMostRecentRole'].mean())
# Out:
# 2.2931972789115647

# %% [markdown]
# ***Retrieve the employee data with maximum years sincs last promotion***

# %%
print(df1.iloc[df1['YearsSinceLastPromotion'].idxmax()])
# Out:
# EmployeeID                       CBCB-9C9D
# FirstName                          Leonerd
# LastName                             Aland
# Gender                                Male
# Age                                     38
# BusinessTravel                 Some Travel
# Department                           Sales
# DistanceFromHome (KM)                   23
# State                                   CA
# Ethnicity                            White
# Education                                4
# EducationField                   Marketing
# JobRole                    Sales Executive
# MaritalStatus                       Single
# Salary                              157718
# StockOptionLevel                         0
# OverTime                               Yes
# HireDate                          4/1/2012
# Attrition                               No
# YearsAtCompany                          10
# YearsInMostRecentRole                    6
# YearsSinceLastPromotion                 10
# ...

# %% [markdown]
# Retrieve the employee data with minimum years sincs last promotion

# %%
print(df1.iloc[df1['YearsSinceLastPromotion'].idxmin()])
# Out:
# EmployeeID                                 8567-5B27
# FirstName                                      Shani
# LastName                                     Deackes
# Gender                                        Female
# Age                                               28
# BusinessTravel                    Frequent Traveller
# Department                                     Sales
# DistanceFromHome (KM)                             32
# State                                             NY
# Ethnicity                  Black or African American
# Education                                          1
# EducationField                      Technical Degree
# JobRole                         Sales Representative
# MaritalStatus                                 Single
# Salary                                         53439
# StockOptionLevel                                   0
# OverTime                                         Yes
# HireDate                                   27/4/2012
# ...

# %% [markdown]
# ***Retrieve the average of years since last promotion***

# %%
print(df1['YearsSinceLastPromotion'].mean())
# Out:
# 3.440816326530612

# %% [markdown]
# ***Promotions and Attrition***

# %%
sns.countplot(x='YearsSinceLastPromotion', data=df1, palette='mako',hue='Attrition')
plt.title('Years Since Last Promotion vs Attrition')
plt.show()

# %% [markdown]
# ***Retrieve the employee data with maximum years with current manager***

# %%
print(df1.iloc[df1['YearsWithCurrManager'].idxmax()])
# Out:
# EmployeeID                       DFA9-990E
# FirstName                             Cale
# LastName                           Holston
# Gender                                Male
# Age                                     43
# BusinessTravel                  No Travel
# Department                           Sales
# DistanceFromHome (KM)                   34
# State                                   NY
# Ethnicity                            White
# Education                                4
# EducationField                   Marketing
# JobRole                    Sales Executive
# MaritalStatus                      Married
# Salary                              108315
# StockOptionLevel                         2
# OverTime                                No
# HireDate                         17/1/2012
# Attrition                               No
# YearsAtCompany                          10
# YearsInMostRecentRole                    9
# YearsSinceLastPromotion                 10
# ...

# %% [markdown]
# Retrieve the employee data with minimum years with current manager

# %%
print(df1.iloc[df1['YearsWithCurrManager'].idxmin()])
# Out:
# EmployeeID                       CBCB-9C9D
# FirstName                          Leonerd
# LastName                             Aland
# Gender                                Male
# Age                                     38
# BusinessTravel                 Some Travel
# Department                           Sales
# DistanceFromHome (KM)                   23
# State                                   CA
# Ethnicity                            White
# Education                                4
# EducationField                   Marketing
# JobRole                    Sales Executive
# MaritalStatus                       Single
# Salary                              157718
# StockOptionLevel                         0
# OverTime                               Yes
# HireDate                          4/1/2012
# Attrition                               No
# YearsAtCompany                          10
# YearsInMostRecentRole                    6
# YearsSinceLastPromotion                 10
# ...

# %% [markdown]
# Retrieve the average of years with current manager

# %%
print(df1['YearsWithCurrManager'].mean())
# Out:
# 2.239455782312925

# %% [markdown]
# ***Years With Current Manager & Attrition***

# %%
sns.countplot(hue='Attrition', x='YearsWithCurrManager', data=df1, palette='mako')
plt.title('Years with Current Manager vs Attrition')
plt.show()

# %% [markdown]
# Retrieve the average of salaries

# %%
plt.figure(figsize=(8,8))
sns.countplot(x='Ethnicity',data=df1,hue='Ethnicity',palette='mako')
plt.xticks(rotation=90)
plt.title('Ethnicity')
plt.show()
print(df1['Ethnicity'].value_counts())
print(df1['Ethnicity'].unique())
# Out:
# Ethnicity
# White                               860
# Black or African American           207
# Mixed or multiple ethnic groups     198
# Asian or Asian American             113
# American Indian or Alaska Native     50
# Native Hawaiian                      26
# Other                                16
# Name: count, dtype: int64
# ['White' 'Asian or Asian American' 'Mixed or multiple ethnic groups'
#  'Black or African American' 'Native Hawaiian ' 'Other '
#  'American Indian or Alaska Native']

# %% [markdown]
# ***Salary Distribution***

# %%
sns.histplot(df1['Salary'], bins=20, kde=True, palette='mako')
plt.title('Salary Distribution')
plt.show()
print("Average Salary:", df1['Salary'].mean())
# Out:
# /tmp/ipython-input-2182696875.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df1['Salary'], bins=20, kde=True, palette='mako')
# Average Salary: 112956.49795918367

# %% [markdown]
# ***Education Field***

# %%
sns.countplot(x='EducationField',data=df1,hue='EducationField',palette='mako')
plt.title('EducationField')
plt.xticks(rotation=45)
plt.show()
print(df1['EducationField'].value_counts())
# Out:
# EducationField
# Computer Science       440
# Information Systems    363
# Marketing              325
# Economics              101
# Business Studies        94
# Other                   82
# Technical Degree        38
# Human Resources         27
# Name: count, dtype: int64

# %% [markdown]
# ***Marital Status***

# %%
sns.countplot(x='MaritalStatus',data=df1,hue='MaritalStatus',palette='mako')
plt.title('MaritalStatus')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ***Marital Status & Attrition***

# %%
sns.countplot(x='MaritalStatus',hue='Attrition',data=df1,palette='mako')
plt.title('Marital Status vs Attrition')
plt.show()

# %% [markdown]
# ***Job Role***

# %%
sns.countplot(x='JobRole',data=df1,hue='JobRole',palette='mako')
plt.title('JobRole')
plt.xticks(rotation=90)
plt.show()
print(df1['JobRole'].value_counts())
# Out:
# JobRole
# Sales Executive              327
# Software Engineer            294
# Data Scientist               261
# Machine Learning Engineer    146
# Senior Software Engineer     132
# Sales Representative          83
# Engineering Manager           75
# Analytics Manager             52
# Manager                       37
# HR Executive                  28
# Recruiter                     24
# HR Business Partner            7
# HR Manager                     4
# Name: count, dtype: int64

# %% [markdown]
# ***Job Role & Salary***

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='JobRole', y='Salary', data=df1, palette='husl',hue='JobRole',legend=False)
plt.xticks(rotation=45)
plt.title('Salary by Job Role')
plt.show()

# %% [markdown]
# ***Gender Distribution***

# %%
df1['Gender'].value_counts().plot(kind='pie',labels=df1['Gender'].unique(),autopct='%1.1f%%',startangle=0)
plt.title('Gender')
plt.show()
print(df1['Gender'].value_counts())
# Out:
# Gender
# Female               675
# Male                 651
# Non-Binary           124
# Prefer Not To Say     20
# Name: count, dtype: int64

# %% [markdown]
# ***Gender & Atrrition***

# %%
sns.countplot(x='Gender',data=df1,hue='Attrition',palette='mako')
plt.title('Attrition Count')
plt.show()
print(df1.groupby('Gender')['Attrition'].value_counts())
# Out:
# Gender             Attrition
# Female             No           571
#                    Yes          104
# Male               No           537
#                    Yes          114
# Non-Binary         No           105
#                    Yes           19
# Prefer Not To Say  No            20
# Name: count, dtype: int64

# %% [markdown]
# ***Attrition***

# %%
df1['Attrition'].value_counts().plot(kind='pie',labels=df1['Attrition'].unique(),autopct='%1.1f%%',startangle=90)
plt.title('Attrition')
plt.show()
print(df1['Attrition'].value_counts())
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
sns.countplot(x='Attrition', data=df1,hue='Attrition',palette='mako')
plt.title('Attrition Count')
plt.show()
print(df1['Attrition'].value_counts())
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %% [markdown]
# ***Department Distribution***

# %%
df1['Department'].value_counts().plot(kind='pie',labels=df1['Department'].unique(),autopct='%1.1f%%',startangle=90)
plt.title('Department')
plt.show()
print(df1['Department'].value_counts())
# Out:
# Department
# Technology         961
# Sales              446
# Human Resources     63
# Name: count, dtype: int64

# %% [markdown]
# ***Employees per Department***

# %%
sns.countplot(x='Department',data=df1,palette='mako',hue='Department')
plt.title('Employees per Department')
plt.show()
print(df1['Department'].value_counts())
# Out:
# Department
# Technology         961
# Sales              446
# Human Resources     63
# Name: count, dtype: int64

# %% [markdown]
# ***Attrition per Department***

# %%
sns.countplot(x='Department',data=df1,hue='Attrition',palette='mako')
plt.title('Attrition per Department')
plt.show()
print(df1.groupby('Department')['Attrition'].value_counts())
# Out:
# Department       Attrition
# Human Resources  No            51
#                  Yes           12
# Sales            No           354
#                  Yes           92
# Technology       No           828
#                  Yes          133
# Name: count, dtype: int64

# %% [markdown]
# ***Business Travel Distribution***

# %%
df1['BusinessTravel'].value_counts().plot(kind='pie',labels=df1['BusinessTravel'].unique(),autopct='%1.1f%%',startangle=90)
plt.title('BusinessTravel')
plt.show()
print(df1['BusinessTravel'].value_counts())
print(df1['BusinessTravel'].unique())
# Out:
# BusinessTravel
# Some Travel           1043
# Frequent Traveller     277
# No Travel              150
# Name: count, dtype: int64
# ['Some Travel' 'No Travel ' 'Frequent Traveller']

# %% [markdown]
# ***State Distribution***

# %%
plt.figure(figsize=(8,8))
df1['State'].value_counts().plot(kind='pie',labels=df1['State'].unique(),autopct='%1.1f%%',startangle=90)
plt.xticks(rotation=360)
plt.title('State')
plt.show()
print(df1['State'].value_counts())
print(df1['State'].unique())
# Out:
# State
# CA    875
# NY    419
# IL    176
# Name: count, dtype: int64
# ['IL' 'CA' 'NY']

# %% [markdown]
# ***Retieve the data of the farthest Employee***

# %%
print(df1.iloc[df1['DistanceFromHome (KM)'].idxmax()])
# Out:
# EmployeeID                                 D906-B674
# FirstName                                        Uta
# LastName                                      Melmar
# Gender                                        Female
# Age                                               42
# BusinessTravel                            No Travel
# Department                                Technology
# DistanceFromHome (KM)                             45
# State                                             NY
# Ethnicity                  Black or African American
# Education                                          3
# EducationField                   Information Systems
# JobRole                          Engineering Manager
# MaritalStatus                                Married
# Salary                                        259284
# StockOptionLevel                                   1
# OverTime                                          No
# HireDate                                    9/1/2012
# ...

# %% [markdown]
# ***Retieve the data of the Closet Employee***

# %%
print(df1.iloc[df1['DistanceFromHome (KM)'].idxmin()])
# Out:
# EmployeeID                       C6EC-FEB5
# FirstName                         Charlena
# LastName                       Severwright
# Gender                              Female
# Age                                     38
# BusinessTravel                 Some Travel
# Department                           Sales
# DistanceFromHome (KM)                    1
# State                                   CA
# Ethnicity                            White
# Education                                1
# EducationField                   Economics
# JobRole                    Sales Executive
# MaritalStatus                       Single
# Salary                              151141
# StockOptionLevel                         0
# OverTime                                No
# HireDate                         19/1/2012
# Attrition                               No
# YearsAtCompany                          10
# YearsInMostRecentRole                    3
# YearsSinceLastPromotion                  6
# ...

# %% [markdown]
# ***Average Distance From Home***

# %%
print(df1['DistanceFromHome (KM)'].mean())
# Out:
# 22.502721088435376

# %% [markdown]
# ***Distance From Home & Attrition***

# %%
plt.figure(figsize=(15,15))
sns.countplot(x='DistanceFromHome (KM)',hue='Attrition', data=df1, palette='Set2')
plt.title('Distance From Home vs Attrition')
plt.show()

# %% [markdown]
# ***Age distribution***

# %%
sns.histplot(x='Age',data=df1,bins=20,palette='mako')
plt.title('Age Distribution')
plt.show()
# Out:
# /tmp/ipython-input-2279016382.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x='Age',data=df1,bins=20,palette='mako')

# %% [markdown]
# ***Age & Attrition***

# %%
plt.figure(figsize=(15,15))
sns.countplot(x='Age',data=df1,hue='Attrition',palette='mako')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ***Attrition Per Overtime***

# %%
df1['OverTime'].value_counts()
sns.countplot(x='OverTime',data=df1,hue='Attrition',palette='mako')
plt.title('Attrition Count')
plt.show()
print(df1.groupby('OverTime')['Attrition'].value_counts())
# Out:
# OverTime  Attrition
# No        No           944
#           Yes          110
# Yes       No           289
#           Yes          127
# Name: count, dtype: int64

# %% [markdown]
# ***Education Level & Salary***

# %%
sns.boxplot(x='Education', y='Salary', data=df1, palette='mako',hue='Education',legend=False)
plt.title('Salary vs Education Level')
plt.show()

# %% [markdown]
# ***Education Level & Attrition***

# %%
sns.countplot(x='Education',data=df1,hue='Attrition',palette='mako')
plt.title('Education Level & Attrition')
plt.show()
print(df1['Education'].value_counts())
# Out:
# Education
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: count, dtype: int64
